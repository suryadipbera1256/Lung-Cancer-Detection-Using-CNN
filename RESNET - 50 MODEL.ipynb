# %%
import tensorflow as tf
from keras import layers
from keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
train_path = (r"C:\Users\SURYADIP\OneDrive\Desktop\Lung-Cencer\Lung-Cancer-Detection-Using-CNN\Data\train")
val_path = (r"C:\Users\SURYADIP\OneDrive\Desktop\Lung-Cencer\Lung-Cancer-Detection-Using-CNN\Data\valid")
test_path = (r"C:\Users\SURYADIP\OneDrive\Desktop\Lung-Cencer\Lung-Cancer-Detection-Using-CNN\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # RESNET 50 MODEL

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(input_shape=(350, 350,3),
                      include_top=False, weights="imagenet", 
                      pooling='max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.models import Sequential
model_resnet = Sequential()
model_resnet.add(base_model)
model_resnet.add(Dense(4, activation='sigmoid'))

# %%
model_resnet.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001), 
                     loss = 'categorical_crossentropy', 
                     metrics = ['accuracy'])

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath = "./best_model.keras",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
resnet = model_resnet.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back 
    )
# Out:
# Epoch 1/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.3559 - loss: 1.4787
# Epoch 1: val_accuracy improved from None to 0.41429, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 76s 547ms/step - accuracy: 0.3783 - loss: 1.3538 - val_accuracy: 0.4143 - val_loss: 1.3140
# Epoch 2/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 52s 435ms/step - accuracy: 0.4000 - loss: 1.2004
# Epoch 2: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4000 - loss: 1.2004 - val_accuracy: 0.4000 - val_loss: 1.3341
# Epoch 3/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.4133 - loss: 1.2559
# Epoch 3: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 61s 499ms/step - accuracy: 0.4227 - loss: 1.2341 - val_accuracy: 0.4000 - val_loss: 1.2553
# Epoch 4/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 48s 401ms/step - accuracy: 0.4000 - loss: 1.3720
# Epoch 4: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.4000 - loss: 1.3720 - val_accuracy: 0.3714 - val_loss: 1.1985
# Epoch 5/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.4193 - loss: 1.2022
# Epoch 5: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 58s 476ms/step - accuracy: 0.4309 - loss: 1.1865 - val_accuracy: 0.3714 - val_loss: 1.1860
# Epoch 6/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:00 502ms/step - accuracy: 0.8000 - loss: 0.9549
# Epoch 6: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8000 - loss: 0.9549 - val_accuracy: 0.3286 - val_loss: 1.3098
# Epoch 7/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.4368 - loss: 1.1325
# Epoch 7: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 63s 516ms/step - accuracy: 0.4391 - loss: 1.1526 - val_accuracy: 0.3571 - val_loss: 1.1096
# Epoch 8/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 57s 476ms/step - accuracy: 0.4000 - loss: 1.3632
# Epoch 8: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.4000 - loss: 1.3632 - val_accuracy: 0.3429 - val_loss: 1.1780
# Epoch 9/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.4557 - loss: 1.1083
# Epoch 9: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 62s 504ms/step - accuracy: 0.4539 - loss: 1.1314 - val_accuracy: 0.3714 - val_loss: 1.0934
# Epoch 10/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 56s 470ms/step - accuracy: 0.6000 - loss: 0.9766
# Epoch 10: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.6000 - loss: 0.9766 - val_accuracy: 0.3714 - val_loss: 1.1041
# Epoch 11/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.4556 - loss: 1.1212
# Epoch 11: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 75s 612ms/step - accuracy: 0.4688 - loss: 1.1019 - val_accuracy: 0.3429 - val_loss: 1.2179
# Epoch 12/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:18 647ms/step - accuracy: 0.4000 - loss: 1.0182
# Epoch 12: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.4000 - loss: 1.0182 - val_accuracy: 0.3429 - val_loss: 1.1315
# Epoch 13/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 778ms/step - accuracy: 0.4928 - loss: 1.0724
# Epoch 13: val_accuracy improved from 0.41429 to 0.47143, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 113s 923ms/step - accuracy: 0.5000 - loss: 1.0704 - val_accuracy: 0.4714 - val_loss: 1.1148
# Epoch 14/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 51s 424ms/step - accuracy: 0.4000 - loss: 1.0144
# Epoch 14: val_accuracy improved from 0.47143 to 0.48571, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.4000 - loss: 1.0144 - val_accuracy: 0.4857 - val_loss: 1.0653
# Epoch 15/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.4524 - loss: 1.1346
# Epoch 15: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 82s 666ms/step - accuracy: 0.4688 - loss: 1.1008 - val_accuracy: 0.4857 - val_loss: 1.0659
# Epoch 16/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:12 596ms/step - accuracy: 0.6000 - loss: 1.0185
# Epoch 16: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.6000 - loss: 1.0185 - val_accuracy: 0.4714 - val_loss: 1.0580
# Epoch 17/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.4872 - loss: 1.0527
# Epoch 17: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 80s 656ms/step - accuracy: 0.4753 - loss: 1.0856 - val_accuracy: 0.3857 - val_loss: 1.1273
# Epoch 18/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:12 601ms/step - accuracy: 0.6000 - loss: 0.8084
# Epoch 18: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.6000 - loss: 0.8084 - val_accuracy: 0.4000 - val_loss: 1.0976
# Epoch 19/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4439 - loss: 1.0839
# Epoch 19: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.4490 - loss: 1.0660 - val_accuracy: 0.4714 - val_loss: 1.0825
# Epoch 20/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:23 1s/step - accuracy: 0.4000 - loss: 1.0713
# Epoch 20: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.4000 - loss: 1.0713 - val_accuracy: 0.4571 - val_loss: 1.0426
# Epoch 21/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4785 - loss: 1.0733
# Epoch 21: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 699s 6s/step - accuracy: 0.4622 - loss: 1.0913 - val_accuracy: 0.4714 - val_loss: 1.0868
# Epoch 22/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 31:58:31 951s/step - accuracy: 0.4000 - loss: 1.1547
# Epoch 22: val_accuracy improved from 0.48571 to 0.50000, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1711s 6s/step - accuracy: 0.4000 - loss: 1.1547 - val_accuracy: 0.5000 - val_loss: 1.0252
# Epoch 23/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.4935 - loss: 1.0614
# Epoch 23: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 103s 843ms/step - accuracy: 0.4934 - loss: 1.0615 - val_accuracy: 0.4714 - val_loss: 1.0100
# Epoch 24/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:25 708ms/step - accuracy: 0.6000 - loss: 0.8529
# Epoch 24: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.6000 - loss: 0.8529 - val_accuracy: 0.5000 - val_loss: 1.0081
# Epoch 25/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.4756 - loss: 1.0672
# Epoch 25: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 101s 830ms/step - accuracy: 0.4934 - loss: 1.0581 - val_accuracy: 0.4429 - val_loss: 1.1717
# Epoch 26/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:57 972ms/step - accuracy: 0.6000 - loss: 0.7586
# Epoch 26: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 14s 111ms/step - accuracy: 0.6000 - loss: 0.7586 - val_accuracy: 0.4429 - val_loss: 1.1296
# Epoch 27/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.4639 - loss: 1.0426
# Epoch 27: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 115s 943ms/step - accuracy: 0.4556 - loss: 1.0604 - val_accuracy: 0.4286 - val_loss: 1.0242
# Epoch 28/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:47 887ms/step - accuracy: 0.4000 - loss: 1.1316
# Epoch 28: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - accuracy: 0.4000 - loss: 1.1316 - val_accuracy: 0.3857 - val_loss: 1.0258
# Epoch 29/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4872 - loss: 1.0218
# Epoch 29: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.4737 - loss: 1.0564 - val_accuracy: 0.5000 - val_loss: 1.0034
# Epoch 30/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:47 2s/step - accuracy: 0.2000 - loss: 1.1204
# Epoch 30: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 23s 174ms/step - accuracy: 0.2000 - loss: 1.1204 - val_accuracy: 0.3857 - val_loss: 1.0843
# Epoch 31/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5030 - loss: 1.0473
# Epoch 31: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.4901 - loss: 1.0548 - val_accuracy: 0.4143 - val_loss: 1.0206
# Epoch 32/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:33 774ms/step - accuracy: 0.2000 - loss: 1.0702
# Epoch 32: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - accuracy: 0.2000 - loss: 1.0702 - val_accuracy: 0.3857 - val_loss: 1.0437

# %%
# Loading the Best Fit Model 
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
model = load_model("./best_model.keras")

# %%
# Checking the Accuracy of the Model 
accuracy_resnet = model.evaluate(test_data)[1] 
print(f"The accuracy of the model is = {accuracy_resnet*100} %")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 493ms/step - accuracy: 0.6794 - loss: 0.7482
# The accuracy of the model is = 67.93650984764099 %

# %%
resnet.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot model performance
acc = resnet.history['accuracy']
val_acc = resnet.history['val_accuracy']
loss = resnet.history['loss']
val_loss = resnet.history['val_loss']
epochs_range = range(1, len(resnet.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Prediction

# %%
def chestScanPrediction(path, _model):
    classes_dir = ["Adenocarcinoma","Large cell carcinoma","Normal","Squamous cell carcinoma"]
    # Loading Image
    img = image.load_img(path, target_size=(350,350))
    # Normalizing Image
    norm_img = image.img_to_array(img)/255
    # Converting Image to Numpy Array
    input_arr_img = np.array([norm_img])
    # Getting Predictions
    pred = np.argmax(_model.predict(input_arr_img))
    # Printing Model Prediction
    print(classes_dir[pred])

# %%
path = r"C:\Users\Arnash Das\OneDrive\Desktop\Lung cancer\Data\test\large.cell.carcinoma\000111.png"
chestScanPrediction(path,model_resnet)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 path = r"C:\Users\Arnash Das\OneDrive\Desktop\Lung cancer\Data\test\large.cell.carcinoma\000111.png"
# ----> 2 chestScanPrediction(path,model_resnet)
#
# Cell In[22], line 4, in chestScanPrediction(path, _model)
#       2 classes_dir = ["Adenocarcinoma","Large cell carcinoma","Normal","Squamous cell carcinoma"]
#       3 # Loading Image
# ----> 4 img = image.load_img(path, target_size=(350,350))
#       5 # Normalizing Image
#       6 norm_img = image.img_to_array(img)/255
#
# File c:\Users\SURYADIP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Arnash Das\\OneDrive\\Desktop\\Lung cancer\\Data\\test\\large.cell.carcinoma\\000111.png'
