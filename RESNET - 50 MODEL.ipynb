# %%
import tensorflow as tf
from keras import layers
from keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
train_path = (r"C:\Users\Arnash Das\OneDrive\Desktop\Lung cancer\Data\train")
val_path = (r"C:\Users\Arnash Das\OneDrive\Desktop\Lung cancer\Data\valid")
test_path = (r"C:\Users\Arnash Das\OneDrive\Desktop\Lung cancer\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # RESNET 50 MODEL

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(input_shape=(350, 350,3),
                      include_top=False, weights="imagenet", 
                      pooling='max')

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.models import Sequential
model_resnet = Sequential()
model_resnet.add(base_model)
model_resnet.add(Dense(4, activation='sigmoid'))

# %%
model_resnet.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001), 
                     loss = 'categorical_crossentropy', 
                     metrics = ['accuracy'])

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath = "./best_model.keras",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
resnet = model_resnet.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back 
    )
# Out:
# Epoch 1/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.3251 - loss: 1.6991
# Epoch 1: val_accuracy improved from -inf to 0.30000, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.3249 - loss: 1.6980 - val_accuracy: 0.3000 - val_loss: 1.4417
# Epoch 2/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:51 924ms/step - accuracy: 0.2000 - loss: 1.3683
# Epoch 2: val_accuracy improved from 0.30000 to 0.34286, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.2000 - loss: 1.3683 - val_accuracy: 0.3429 - val_loss: 1.3617
# Epoch 3/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3051 - loss: 1.4357
# Epoch 3: val_accuracy did not improve from 0.34286
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.3055 - loss: 1.4352 - val_accuracy: 0.2857 - val_loss: 1.3728
# Epoch 4/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:12 597ms/step - accuracy: 0.6000 - loss: 1.0749
# Epoch 4: val_accuracy did not improve from 0.34286
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6000 - loss: 1.0749 - val_accuracy: 0.3000 - val_loss: 1.4685
# Epoch 5/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4205 - loss: 1.2751
# Epoch 5: val_accuracy improved from 0.34286 to 0.41429, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.4205 - loss: 1.2749 - val_accuracy: 0.4143 - val_loss: 1.2404
# Epoch 6/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:02 2s/step - accuracy: 0.4000 - loss: 1.1707
# Epoch 6: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 32s 251ms/step - accuracy: 0.4000 - loss: 1.1707 - val_accuracy: 0.3143 - val_loss: 1.2877
# Epoch 7/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4046 - loss: 1.1818
# Epoch 7: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.4050 - loss: 1.1817 - val_accuracy: 0.4143 - val_loss: 1.1055
# Epoch 8/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:19 2s/step - accuracy: 0.6000 - loss: 0.8703
# Epoch 8: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 30s 234ms/step - accuracy: 0.6000 - loss: 0.8703 - val_accuracy: 0.4143 - val_loss: 1.1038
# Epoch 9/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4630 - loss: 1.1708
# Epoch 9: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.4630 - loss: 1.1706 - val_accuracy: 0.3857 - val_loss: 1.1092
# Epoch 10/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:56 1s/step - accuracy: 0.6000 - loss: 0.9148
# Epoch 10: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 26s 204ms/step - accuracy: 0.6000 - loss: 0.9148 - val_accuracy: 0.3429 - val_loss: 1.1625
# Epoch 11/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4767 - loss: 1.1167
# Epoch 11: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - accuracy: 0.4766 - loss: 1.1168 - val_accuracy: 0.3429 - val_loss: 1.2609
# Epoch 12/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:49 2s/step - accuracy: 0.6000 - loss: 1.0330
# Epoch 12: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 29s 221ms/step - accuracy: 0.6000 - loss: 1.0330 - val_accuracy: 0.3429 - val_loss: 1.2445
# Epoch 13/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4509 - loss: 1.1225
# Epoch 13: val_accuracy did not improve from 0.41429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 296s 2s/step - accuracy: 0.4510 - loss: 1.1225 - val_accuracy: 0.3714 - val_loss: 1.1676
# Epoch 14/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:25 2s/step - accuracy: 0.0000e+00 - loss: 1.4340
# Epoch 14: val_accuracy improved from 0.41429 to 0.45714, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 312ms/step - accuracy: 0.0000e+00 - loss: 1.4340 - val_accuracy: 0.4571 - val_loss: 1.1264
# Epoch 15/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4791 - loss: 1.1341
# Epoch 15: val_accuracy did not improve from 0.45714
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.4790 - loss: 1.1338 - val_accuracy: 0.3857 - val_loss: 1.1103
# Epoch 16/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:48 2s/step - accuracy: 0.6000 - loss: 1.0786
# Epoch 16: val_accuracy did not improve from 0.45714
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 31s 239ms/step - accuracy: 0.6000 - loss: 1.0786 - val_accuracy: 0.3857 - val_loss: 1.1852
# Epoch 17/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5209 - loss: 1.0764
# Epoch 17: val_accuracy did not improve from 0.45714
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.5206 - loss: 1.0766 - val_accuracy: 0.4571 - val_loss: 1.0615
# Epoch 18/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:01 2s/step - accuracy: 0.6000 - loss: 1.1498
# Epoch 18: val_accuracy did not improve from 0.45714
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 31s 244ms/step - accuracy: 0.6000 - loss: 1.1498 - val_accuracy: 0.4429 - val_loss: 1.1005
# Epoch 19/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4807 - loss: 1.0944
# Epoch 19: val_accuracy improved from 0.45714 to 0.47143, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.4807 - loss: 1.0943 - val_accuracy: 0.4714 - val_loss: 1.0815
# Epoch 20/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:17 2s/step - accuracy: 0.4000 - loss: 0.9755
# Epoch 20: val_accuracy did not improve from 0.47143
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 31s 235ms/step - accuracy: 0.4000 - loss: 0.9755 - val_accuracy: 0.4000 - val_loss: 1.1587
# Epoch 21/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5264 - loss: 1.0633
# Epoch 21: val_accuracy did not improve from 0.47143
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.5262 - loss: 1.0633 - val_accuracy: 0.4286 - val_loss: 1.0556
# Epoch 22/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:42 1s/step - accuracy: 0.3333 - loss: 1.1884
# Epoch 22: val_accuracy did not improve from 0.47143
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 31s 241ms/step - accuracy: 0.3333 - loss: 1.1884 - val_accuracy: 0.4714 - val_loss: 1.0351
# Epoch 23/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4660 - loss: 1.0531
# Epoch 23: val_accuracy improved from 0.47143 to 0.48571, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.4659 - loss: 1.0534 - val_accuracy: 0.4857 - val_loss: 1.0319
# Epoch 24/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:04 2s/step - accuracy: 0.6000 - loss: 0.7378
# Epoch 24: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 24s 187ms/step - accuracy: 0.6000 - loss: 0.7378 - val_accuracy: 0.4714 - val_loss: 1.0195
# Epoch 25/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5148 - loss: 1.0035
# Epoch 25: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.5146 - loss: 1.0038 - val_accuracy: 0.3571 - val_loss: 1.1786
# Epoch 26/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:21 2s/step - accuracy: 0.2000 - loss: 1.3113
# Epoch 26: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 31s 238ms/step - accuracy: 0.2000 - loss: 1.3113 - val_accuracy: 0.4000 - val_loss: 0.9947
# Epoch 27/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4768 - loss: 1.0732
# Epoch 27: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.4767 - loss: 1.0733 - val_accuracy: 0.4000 - val_loss: 1.0011
# Epoch 28/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:58 2s/step - accuracy: 0.6000 - loss: 1.0821
# Epoch 28: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 30s 235ms/step - accuracy: 0.6000 - loss: 1.0821 - val_accuracy: 0.4714 - val_loss: 1.0461
# Epoch 29/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5016 - loss: 1.0416
# Epoch 29: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.5015 - loss: 1.0418 - val_accuracy: 0.4000 - val_loss: 1.0873
# Epoch 30/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:22 2s/step - accuracy: 0.2000 - loss: 1.3245
# Epoch 30: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 25s 192ms/step - accuracy: 0.2000 - loss: 1.3245 - val_accuracy: 0.4000 - val_loss: 1.0435
# Epoch 31/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5593 - loss: 0.9938
# Epoch 31: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.5589 - loss: 0.9942 - val_accuracy: 0.3571 - val_loss: 1.1022
# Epoch 32/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:26 2s/step - accuracy: 0.4000 - loss: 0.9422
# Epoch 32: val_accuracy did not improve from 0.48571
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 28s 220ms/step - accuracy: 0.4000 - loss: 0.9422 - val_accuracy: 0.4571 - val_loss: 1.0272

# %%
# Loading the Best Fit Model 
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
model = load_model("./best_model.keras")

# %%
# Checking the Accuracy of the Model 
accuracy_resnet = model.evaluate(test_data)[1] 
print(f"The accuracy of the model is = {accuracy_resnet*100} %")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.7289 - loss: 0.6374
# The accuracy of the model is = 75.23809671401978 %

# %%
resnet.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot model performance
acc = resnet.history['accuracy']
val_acc = resnet.history['val_accuracy']
loss = resnet.history['loss']
val_loss = resnet.history['val_loss']
epochs_range = range(1, len(resnet.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Prediction

# %%
def chestScanPrediction(path, _model):
    classes_dir = ["Adenocarcinoma","Large cell carcinoma","Normal","Squamous cell carcinoma"]
    # Loading Image
    img = image.load_img(path, target_size=(350,350))
    # Normalizing Image
    norm_img = image.img_to_array(img)/255
    # Converting Image to Numpy Array
    input_arr_img = np.array([norm_img])
    # Getting Predictions
    pred = np.argmax(_model.predict(input_arr_img))
    # Printing Model Prediction
    print(classes_dir[pred])

# %%
path = r"C:\Users\Arnash Das\OneDrive\Desktop\Lung cancer\Data\test\large.cell.carcinoma\000111.png"
chestScanPrediction(path,model_resnet)
