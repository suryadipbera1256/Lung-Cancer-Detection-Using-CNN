# %%
import sys, subprocess, os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # reduce verbose TF logs
try:
    import tensorflow as tf
except ModuleNotFoundError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow"])
    import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import Model

import sys, subprocess, os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

try:
    import tensorflow as tf
except ModuleNotFoundError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow"])
    import tensorflow as tf

# Use tensorflow.keras consistently (do NOT mix with standalone "keras")
from tensorflow.keras.models import Sequential, load_model, Model
# use layers from the already-imported tensorflow to avoid mixing standalone "keras"
layers = tf.keras.layers
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import EfficientNetB0, VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.applications import EfficientNetB0


from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
# %pip install matplotlib

import os
try:
    import cv2
except ModuleNotFoundError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "opencv-python-headless"])
    import cv2

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
try:
    import pandas as pd
except ModuleNotFoundError:
    pass

# %pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: matplotlib in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (3.10.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\suryadip\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: pyparsing>=3 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suryadip\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in c:\users\suryadip\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suryadip\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\suryadip\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
train_path = (r"C:\Users\SURYADIP\OneDrive\Desktop\Lung-Cencer\Lung-Cancer-Detection-Using-CNN\Data\train")
val_path = (r"C:\Users\SURYADIP\OneDrive\Desktop\Lung-Cencer\Lung-Cancer-Detection-Using-CNN\Data\valid")
test_path = (r"C:\Users\SURYADIP\OneDrive\Desktop\Lung-Cencer\Lung-Cancer-Detection-Using-CNN\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # CNN MODEL

# %%
model = Sequential() 

# Convolutional Layer with input shape (350,350,3)
model.add(Conv2D(filters=32, kernel_size= (3,3), activation= 'relu', input_shape=(350,350,3)) )

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=4, activation='sigmoid'))



# Compile the model

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']  )
 
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 348, 348, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 346, 346, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 173, 173, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 171, 171, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 85, 85, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 83, 83, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 41, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 41, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 215168)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │    13,770,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,873,572 (52.92 MB)
#  Trainable params: 13,873,572 (52.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./best_model.keras",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [mc];

# %%
# %pip install scipy

# Fitting the Model
cnn = model.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Collecting scipy
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#      ---------------------------------------- 41.3/41.3 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\suryadip\appdata\local\programs\python\python310\lib\site-packages (from scipy) (2.2.6)
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Epoch 1/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.2877 - loss: 1.5207
# Epoch 1: val_accuracy improved from None to 0.42857, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 27s 212ms/step - accuracy: 0.3668 - loss: 1.3217 - val_accuracy: 0.4286 - val_loss: 1.1372
# Epoch 2/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 24s 199ms/step - accuracy: 0.6000 - loss: 0.8697
# Epoch 2: val_accuracy did not improve from 0.42857
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6000 - loss: 0.8697 - val_accuracy: 0.2857 - val_loss: 1.3375
# Epoch 3/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.4263 - loss: 1.2119
# Epoch 3: val_accuracy did not improve from 0.42857
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 25s 208ms/step - accuracy: 0.4803 - loss: 1.1274 - val_accuracy: 0.2714 - val_loss: 1.4210
# Epoch 4/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 24s 204ms/step - accuracy: 0.6000 - loss: 0.7459
# Epoch 4: val_accuracy did not improve from 0.42857
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6000 - loss: 0.7459 - val_accuracy: 0.2286 - val_loss: 1.7240
# Epoch 5/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.4564 - loss: 1.1307
# Epoch 5: val_accuracy did not improve from 0.42857
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 25s 207ms/step - accuracy: 0.4688 - loss: 1.1305 - val_accuracy: 0.4143 - val_loss: 1.1052
# Epoch 6/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 24s 201ms/step - accuracy: 0.4000 - loss: 0.8252
# Epoch 6: val_accuracy did not improve from 0.42857
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4000 - loss: 0.8252 - val_accuracy: 0.4286 - val_loss: 1.0795
# Epoch 7/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4936 - loss: 1.0354
# Epoch 7: val_accuracy improved from 0.42857 to 0.44286, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 27s 217ms/step - accuracy: 0.4967 - loss: 1.0182 - val_accuracy: 0.4429 - val_loss: 0.9527
# Epoch 8/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 22s 186ms/step - accuracy: 0.8000 - loss: 0.8578
# Epoch 8: val_accuracy improved from 0.44286 to 0.50000, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8000 - loss: 0.8578 - val_accuracy: 0.5000 - val_loss: 0.9562
# Epoch 9/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5007 - loss: 1.0054
# Epoch 9: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 27s 221ms/step - accuracy: 0.5049 - loss: 1.0071 - val_accuracy: 0.3714 - val_loss: 0.9702
# Epoch 10/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 26s 215ms/step - accuracy: 0.4000 - loss: 0.8919
# Epoch 10: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4000 - loss: 0.8919 - val_accuracy: 0.3714 - val_loss: 0.9889
# Epoch 11/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.4463 - loss: 1.0651
# Epoch 11: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 34s 282ms/step - accuracy: 0.4737 - loss: 1.0234 - val_accuracy: 0.4429 - val_loss: 0.9558
# Epoch 12/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 44s 370ms/step - accuracy: 0.4000 - loss: 1.0941
# Epoch 12: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4000 - loss: 1.0941 - val_accuracy: 0.3857 - val_loss: 0.9534
# Epoch 13/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4758 - loss: 0.9890
# Epoch 13: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 339ms/step - accuracy: 0.5132 - loss: 0.9653 - val_accuracy: 0.4857 - val_loss: 0.9565
# Epoch 14/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 39s 322ms/step - accuracy: 0.2000 - loss: 1.1581
# Epoch 14: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2000 - loss: 1.1581 - val_accuracy: 0.4714 - val_loss: 0.9640
# Epoch 15/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.4980 - loss: 0.9773
# Epoch 15: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 349ms/step - accuracy: 0.5197 - loss: 0.9774 - val_accuracy: 0.4714 - val_loss: 0.9658
# Epoch 16/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 37s 313ms/step - accuracy: 0.8000 - loss: 0.6932
# Epoch 16: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8000 - loss: 0.6932 - val_accuracy: 0.4857 - val_loss: 0.9594
# Epoch 17/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.5179 - loss: 0.9669
# Epoch 17: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.5263 - loss: 0.9456 - val_accuracy: 0.3714 - val_loss: 0.9950
# Epoch 18/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 35s 289ms/step - accuracy: 0.4000 - loss: 0.8367
# Epoch 18: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.4000 - loss: 0.8367 - val_accuracy: 0.3429 - val_loss: 1.0155
# Epoch 19/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5527 - loss: 0.9817
# Epoch 19: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.5296 - loss: 0.9715 - val_accuracy: 0.4286 - val_loss: 0.9627
# Epoch 20/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.6000 - loss: 0.8126
# Epoch 20: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6000 - loss: 0.8126 - val_accuracy: 0.4571 - val_loss: 0.9409
# Epoch 21/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5723 - loss: 0.9408
# Epoch 21: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 341ms/step - accuracy: 0.5115 - loss: 0.9805 - val_accuracy: 0.4143 - val_loss: 0.9946
# Epoch 22/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 48s 404ms/step - accuracy: 0.6000 - loss: 0.9238
# Epoch 22: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6000 - loss: 0.9238 - val_accuracy: 0.4143 - val_loss: 0.9968
# Epoch 23/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.5531 - loss: 0.9551
# Epoch 23: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 44s 363ms/step - accuracy: 0.5395 - loss: 0.9498 - val_accuracy: 0.3714 - val_loss: 0.9960
# Epoch 24/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 48s 397ms/step - accuracy: 0.8000 - loss: 0.6638
# Epoch 24: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8000 - loss: 0.6638 - val_accuracy: 0.4000 - val_loss: 0.9786
# Epoch 25/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5532 - loss: 0.9329
# Epoch 25: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 353ms/step - accuracy: 0.5609 - loss: 0.9319 - val_accuracy: 0.3571 - val_loss: 0.9894
# Epoch 26/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 38s 321ms/step - accuracy: 0.4000 - loss: 0.8118
# Epoch 26: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4000 - loss: 0.8118 - val_accuracy: 0.3286 - val_loss: 1.0041
# Epoch 27/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5229 - loss: 0.9544
# Epoch 27: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.5493 - loss: 0.9367 - val_accuracy: 0.5000 - val_loss: 0.9713
# Epoch 28/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 49s 409ms/step - accuracy: 0.2000 - loss: 1.0828
# Epoch 28: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2000 - loss: 1.0828 - val_accuracy: 0.4714 - val_loss: 0.9873
# Epoch 29/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.5215 - loss: 0.9218
# Epoch 29: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 65s 535ms/step - accuracy: 0.5164 - loss: 0.9120 - val_accuracy: 0.4857 - val_loss: 1.0027
# Epoch 30/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:21 672ms/step - accuracy: 0.2000 - loss: 1.5084
# Epoch 30: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.2000 - loss: 1.5084 - val_accuracy: 0.4857 - val_loss: 1.0185
# Epoch 31/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.5696 - loss: 0.8919
# Epoch 31: val_accuracy improved from 0.50000 to 0.51429, saving model to ./best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 102s 832ms/step - accuracy: 0.5280 - loss: 0.9490 - val_accuracy: 0.5143 - val_loss: 0.9625
# Epoch 32/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:03 521ms/step - accuracy: 0.8000 - loss: 0.5543
# Epoch 32: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8000 - loss: 0.5543 - val_accuracy: 0.5143 - val_loss: 0.9518

# %%
# Loading the Best Fit Model 
model = load_model("./best_model.keras")

# %%
# Checking the Accuracy of the Model 
accuracy_cnn = model.evaluate(test_data)[1] 
print(f"The accuracy of the model is = {accuracy_cnn*100} %")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.5524 - loss: 0.8967
# The accuracy of the model is = 55.23809790611267 %

# %%
cnn.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot model performance
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']
loss = cnn.history['loss']
val_loss = cnn.history['val_loss']
epochs_range = range(1, len(cnn.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()
